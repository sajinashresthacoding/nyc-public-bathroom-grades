# %%
## import libraries
import pandas as pd

# %%
##brought in all the public spaces located in nyc under PIP jurisdiction 

df_all = pd.read_csv("data/PIP-MAPPED.csv")
df_all
# Out:
#           PropNum      Prop ID Boro AMPSDistrict      Prop Name  \
# 0           B210T        B210T    B           10           Park
# 1           B210S        B210S    B           10           Park
# 2           B210R        B210R    B           10           Park
# 3     B210Q-BZ562  B210Q-BZ562    B           10  Coffey Square
# 4           B210Q        B210Q    B           10           Park
# ...           ...          ...  ...          ...            ...
# 6308         XZ89         XZ89    X           04    GREENSTREET
# 6309         XZ60         XZ60    X           09    GREENSTREET
# 6310         XZ58         XZ58    X           04    GREENSTREET
# 6311         XZ57         XZ57    X           03    GREENSTREET
# 6312        XZ56B        XZ56B    X           03    GREENSTREET
#
#           Site Name                             Prop Location  \
# 0              Park  N/B Gowanus Exwy. bet. 85 St. and 86 St.
# 1              Park  S/B Gowanus Exwy. bet. 85 St. and 86 St.
# ...

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6313 entries, 0 to 6312
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PropNum           6313 non-null   object
#  1   Prop ID           6313 non-null   object
#  2   Boro              6313 non-null   object
#  3   AMPSDistrict      6313 non-null   object
#  4   Prop Name         6162 non-null   object
#  5   Site Name         6162 non-null   object
#  6   Prop Location     6311 non-null   object
#  7   Site Location     6311 non-null   object
#  8   Acres             6236 non-null   float64
#  9   Category          5866 non-null   object
#  10  Sub-Category      5041 non-null   object
#  11  Rated             6313 non-null   object
#  12  Reason Not Rated  1282 non-null   object
#  13  Council District  6299 non-null   object
#  14  ZipCode           6292 non-null   object
#  15  COMMUNITYBOARD    6304 non-null   object
# ...

# %%
##

df_all["Category"].unique()
# Out:
# array(['Other', 'Greenstreet', 'Small Park', nan, 'Large Park',
#        'Small Center', 'Playground', 'Property', 'Schoolyard',
#        'Large Center'], dtype=object)

# %%
df_all['Category'].eq("Large Center").value_counts()
# Out:
# False    6296
# True       17
# Name: Category, dtype: int64

# %%
list(df_all["Category"].unique())
# Out:
# ['Other',
#  'Greenstreet',
#  'Small Park',
#  nan,
#  'Large Park',
#  'Small Center',
#  'Playground',
#  'Property',
#  'Schoolyard',
#  'Large Center']

# %%
df_areas = df_all.query("Category == ['Large Center','Large Park', 'Small Park', 'Large Park']")
df_areas
# Out:
#      PropNum    Prop ID Boro AMPSDistrict                     Prop Name  \
# 5      B210P      B210P    B           10           Dan Ross Playground
# 11     B210J      B210J    B           07       Pena Herrera Playground
# 12     B210I      B210I    B           07  Gonzalo Plasencia Playground
# 13     B210H      B210H    B           06       Harold Ickes Playground
# 14     B210G      B210G    B           07        Triangle Three Sixteen
# ...      ...        ...  ...          ...                           ...
# 6271    X045    X045-02    X           01               St. Mary's Park
# 6272    X045    X045-01    X           01               St. Mary's Park
# 6273    X045       X045    X           01               St. Mary's Park
# 6274    X040       X040    X           07                      Poe Park
# 6275    X039  X039-ZN25    X           15               Pelham Bay Park
#
#                          Site Name  \
# 5              Dan Ross Playground
# ...

# %%
df_areas[["Boro", "ComfortStation"]]
# Out:
#      Boro ComfortStation
# 5       B             No
# 11      B            Yes
# 12      B             No
# 13      B             No
# 14      B             No
# ...   ...            ...
# 6271    X             No
# 6272    X            Yes
# 6273    X             No
# 6274    X            Yes
# 6275    X             No
#
# [2886 rows x 2 columns]

# %%
df_areas.groupby("Boro")["ComfortStation"].count()
# Out:
# Boro
# B    745
# M    638
# Q    688
# R    239
# X    542
# Name: ComfortStation, dtype: int64

# %%
df_areas[['Boro','ComfortStation']].value_counts().unstack()
# Out:
# ComfortStation   No  Yes
# Boro
# B               552  193
# M               505  133
# Q               496  192
# R               203   36
# X               417  125

# %%
zipcodes = df_areas[['Boro','ZipCode','ComfortStation',]].value_counts().unstack()
zipcodes
# Out:
# ComfortStation                                          No   Yes
# Boro ZipCode
# B    11207                                            42.0   8.0
#      11211                                            41.0   8.0
#      11215                                            40.0   8.0
#      11201                                            37.0  10.0
#      11212                                            29.0   6.0
# ...                                                    ...   ...
# X    10461, 10464, 10464, 10465, 10469, 10475, 10803   1.0   NaN
#      10467, 10470, 10471, 10705, 10705                 1.0   NaN
#      10463, 10463                                      NaN   1.0
#      10462, 10472                                      1.0   NaN
#      10451, 10452                                      1.0   NaN
#
# [280 rows x 2 columns]

# %%
zipcodes["Yes"].nlargest(5)
# Out:
# Boro  ZipCode
# B     11224      14.0
# M     00083      14.0
#       10002      14.0
# Q     11385      12.0
# B     11201      10.0
# Name: Yes, dtype: float64

# %%
zipcodes["Yes"].nsmallest(5)
# Out:
# Boro  ZipCode
# B     11223                  1.0
#       11219                  1.0
#       11210                  1.0
#       11229, 11234, 11235    1.0
# M     10012                  1.0
# Name: Yes, dtype: float64

# %%
zipcodes["No"].nlargest(5)
# Out:
# Boro  ZipCode
# M     00083      48.0
# X     10457      46.0
# B     11207      42.0
#       11211      41.0
#       11215      40.0
# Name: No, dtype: float64
